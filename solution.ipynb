# %% [markdown]
# ### Hw1: Milena Kamskaia

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv ("Pearson.tsv", sep="\t")

# %%
font = {'fontname':'Comic Sans MS'}

plt.figure(figsize=(35,27))
plt.suptitle("Hw1. Milena K.", **font, fontweight='bold', fontsize=30)

plt.subplot(5,5,(2,6))
plt.scatter(df['Father'], df['Son'], c ="#F67280")
plt.title("Scatter plot", **font)
plt.xlabel("Father's heights (inches)", **font)
plt.ylabel("Son's heights (inches)", **font)


plt.subplot(5,5,11)
plt.hist(df[(df['Father'] == 66.0)]['Son'], facecolor='#F67280', edgecolor='black')
plt.ylim([0, 6])
plt.title("Histogram of Son`s heights if Father`s height (inches) = 66.0", **font)
plt.xlabel("Son`s heights (inches)", **font)
plt.ylabel("Number of occurrences", **font)

plt.subplot(5,5,16)
plt.hist(df[(df['Father'] == 67.8)]['Son'], facecolor='#F67280', edgecolor='black')
plt.ylim([0, 6])
plt.title("Histogram of Son`s heights if Father`s height (inches) = 67.8", **font)
plt.xlabel("Son`s heights (inches)", **font)
plt.ylabel("Number of occurrences", **font)

plt.subplot(5,5,21)
plt.hist(df[(df['Father'] == 68.3)]['Son'], facecolor='#F67280', edgecolor='black')
plt.ylim([0, 6])
plt.title("Histogram of Son`s heights if Father`s height (inches) = 68.3", **font)
plt.xlabel("Son`s heights (inches)", **font)
plt.ylabel("Number of occurrences", **font)

plt.subplot(553)
plt.hist(df[(df['Son'] == 66.3)]['Father'], facecolor='#F67280', edgecolor='black')
plt.ylim([0, 6])
plt.title("Histogram of Father`s heights if Son`s height (inches) = 66.3", **font)
plt.xlabel("Father`s heights (inches)", **font)
plt.ylabel("Number of occurrences", **font)

plt.subplot(554)
plt.hist(df[(df['Son'] == 67.2)]['Father'], facecolor='#F67280', edgecolor='black')
plt.ylim([0, 6])
plt.title("Histogram of Father`s heights if Son`s height (inches) = 67.2", **font)
plt.xlabel("Father`s heights (inches)", **font)
plt.ylabel("Number of occurrences", **font)

plt.subplot(555)
plt.hist(df[(df['Son'] == 68.6)]['Father'], facecolor='#F67280', edgecolor='black')
plt.ylim([0, 6])
plt.title("Histogram of Father`s heights if Son`s height (inches) = 68.6", **font)
plt.xlabel("Father`s heights (inches)", **font)
plt.ylabel("Number of occurrences", **font)
# Out:
# Text(0, 0.5, 'Number of occurrences')
